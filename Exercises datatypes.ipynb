# %% [markdown]
# ## 💻 Exercises  ➞ <span class='label label-default'>List</span>
#
# ### Exercises ➞ <span class='label label-default'>Level 1</span>
#
# 1. Declare a list with more than 5 items with different data types
# 2. Find the length of your list
# 3. Get the first item, the middle item and the last item of the list
# 4. Declare a list **`called my_info`**, put your (name, age, height, marital status, country)
# 5. Declare a list variable named **`mix_fruits`** and assign initial values Guava, Mango, Apple, Pear, Fig, Orange and Banana and print the list.
# 6. Print the list using **[print()]()**
# 7. Print the number of **`mix_fruits`** in the list
# 8. Print the first, middle and last fruit
# 9. Print the list after modifying one of the fruit
# 10. Add an fruit to variable **`mix_fruits`**
# 11. Insert an fruit in the middle of the **`mix_fruits`** list
# 12. Change one of the fruit names to uppercase
# 13. Join the elements in **`mix_fruits`** with a string **`-#-`**
# 14. Check if a certain fruit exists in the **`mix_fruits`** list.
# 15. Sort the list using **[sort()]()** method
# 16. Reverse the list in descending order using **[reverse()]()** method
# 17. Slice out the first 3 fruits from the list
# 18. Slice out the last 3 fruits from the list
# 19. Slice out the middle fruit or fruits from the list
# 20. Remove the first fruit from the list
# 21. Remove the middle fruit or companies from the list
# 22. Remove the last fruit from the list
# 23. Remove all fruits from the list
# 24. Delete the fruits list
# 25. Join the following lists:
#
#     - ```py
#     front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
#     back_end = ['Node','Express', 'MongoDB']
#     ```
#
# 26. After joining the lists in question 25. Copy the joined list and assign it to a variable full_stack. Then insert **`'Python'`** and **`'SQL'`** after **`'Redux'`**
#
#
# ### Exercises ➞ <span class='label label-default'>Level 1</span>
#
# 1. Find the length of the set **`mix_fruits`**
# 2. Add **`'Kiwi'`** to **`mix_fruits`**
# 3. Insert multiple fruits at once to the set **`mix_fruits`**
# 4. Remove one of the fruit from the set **`mix_fruits`**
# 5. What is the difference between **remove** and **discard**
#
#
# ### Exercises ➞ <span class='label label-default'>Level 2</span>
# Use Imaginary values for Set **`A`** and **`B`**
#
# 1. Join **`A`** and **`B`**
# 2. Find **`A`** intersection **`B`**
# 3. Is **`A`** subset of **`B`**
# 4. Are **`A`** and **`B`** disjoint sets
# 5. Join **`A`** with **`B`** and **`B`** with **`A`**
# 6. What is the symmetric difference between A and **`B`**
# 7. Delete the sets completely
#
#
# ### Exercises ➞ <span class='label label-default'>Level 3</span>
#
# 1. Convert the **`num`** to a set and compare the length of the list and the set, which one is bigger?
# 2. Explain the difference between the following data types: **string**, **list**, **tuple** and **set**
# 3. **`I am a researcher and teacher and I love to inspire and teach people.`**. How many unique words have been used in the sentence? Use the **`split()`** methods and set to get the unique words.

# %%
Data_Type = ["String",123,1.1]
print(f"Length of Data_Type: {len(Data_Type)}")

print(f"First element of Data_Type: {Data_Type[0]}")

print(f"Middle element of Data_Type: {Data_Type[1]}")

print(f"Last element of Data_Type: {Data_Type[2]}")

my_info = ["John", 21, 180, "single", "US"]

mix_fruits = ["Guava", "Mango", "Apple","Pear", "Fig", "Orange", "Banana"]

print(mix_fruits)
print(f"Length of mix_fruits: {len(mix_fruits)}")
print(f"First fruit: {mix_fruits[0]}")
print(f"Middle fruit: {mix_fruits[len(mix_fruits)//2]}")
print(f"Last fruit: {mix_fruits[-1]}")

mix_fruits[2] = "Pineapple"
print(f"Updated mix_fruits: {mix_fruits}")

mix_fruits.append("Watermelon")

mix_fruits.insert(len(mix_fruits)//2, "Papaya")

mix_fruits[5] = mix_fruits[5].upper()

mix_fruits = [item + "#" for item in mix_fruits]

if "Mango" in mix_fruits:
    print("Mango found in mix_fruits")
else:
    print("Mango not found in mix_fruits")

mix_fruits.sort()

mix_fruits.reverse()

mix_fruits[0:3]

mix_fruits[-4:-1]

mix_fruits[len(mix_fruits)//2]

mix_fruits.pop(0)

mix_fruits.pop(len(mix_fruits)//2)

mix_fruits.pop(-1)

mix_fruits.clear()

del mix_fruits

front_end = ["HTML", "CSS", "JS", "React", "Redux"]
backend = ["Node", "Express", "MongoDB"]

full_stack =  backend + front_end

full_stack.extend(["Python", "SQL"])



mix_fruits = {"Guava", "Mango", "Apple","Pear", "Fig", "Orange", "Banana"}

print(f"Length of mix_fruits: {len(mix_fruits)}")

mix_fruits.add("Kiwi")

mix_fruits.update(["Papaya", "Watermelon"])

mix_fruits.remove("Fig")

#if remove cannot find the element it raised=s an error while discard just ignores it
# Out:
# Length of Data_Type: 3
# First element of Data_Type: String
# Middle element of Data_Type: 123
# Last element of Data_Type: 1.1
# ['Guava', 'Mango', 'Apple', 'Pear', 'Fig', 'Orange', 'Banana']
# Length of mix_fruits: 7
# First fruit: Guava
# Middle fruit: Pear
# Last fruit: Banana
# Updated mix_fruits: ['Guava', 'Mango', 'Pineapple', 'Pear', 'Fig', 'Orange', 'Banana']
# Mango not found in mix_fruits
# Length of mix_fruits: 7

# %%
A = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}

print(f"Union of A and B: {A.union(b)}")
print(f"Intersection of A and B: {A.intersection(b)}")
print(f"Difference of A and B: {A.difference(b)}")
print(f"Symmetric Difference of A and B: {A.symmetric_difference(b)}")
del A, b

#A, b are not a disjoint set because they have common elements 4 and 5. A and b are not a subset of each other because they have different elements.
# Out:
# Union of A and B: {1, 2, 3, 4, 5, 6, 7, 8}
# Intersection of A and B: {4, 5}
# Difference of A and B: {1, 2, 3}
# Symmetric Difference of A and B: {1, 2, 3, 6, 7, 8}

# %%
num=[1, 2, 3, 4, 5]

Num_Set = set(num)

print(f"Length of Num_Set: {len(Num_Set)}, length of num list: {len(num)}")
#they are equal because the set is created from the list and it contains the same elements as the list.

#the difference between string, list , tuple and set is that string, list and tuple are ordered while set is unordered. String, list and tuple can contain duplicate elements while set cannot contain duplicate elements. String, list and tuple can be indexed while set cannot be indexed. String, list and tuple can be sliced while set cannot be sliced. String, list and tuple can be changed (mutable) while set is mutable but its elements must be immutable.

print(len("I am a researcher and teacher and I love to inspire and teach people.".split()))
# Out:
# Length of Num_Set: 5, length of num list: 5
# 14

# %% [markdown]
# ---
#
# ## 💻 Exercises ➞ <span class='label label-default'>Tuple</span>
#
#
# ### Exercises ➞ <span class='label label-default'>Level 2</span>
#
# 1. The following is a list of 10 students ages:
# ```py
# ages = [19, 23, 19, 25, 21, 20, 25, 26, 25, 24]
# ```
#
# - Sort the list and find the min and max age
# - Add the min age and the max age again to the list
# - Find the median age (one middle item or two middle items divided by two)
# - Find the average age (sum of all items divided by their number )
# - Find the range of the ages (max - min)
# - Compare the value of (min - average) and (max - average), use **[abs()]** method
#
# 2. Find the middle country(ies) in the **[countries list]()**
# 3. Divide the countries list into two equal lists if it is even if not one more country for the first half.
# 4. **`['India', 'Russia', 'China', 'Finland', 'Sweden', 'Norway', 'Denmark']`**. Unpack the first three countries and the rest as scandic countries.
#
#
#
# ---

# %%
ages = [19, 23, 19, 25, 21, 20, 25, 26, 25, 24]

ages.sort()
min_age = ages[0]
max_age = ages[-1]

ages.append(min_age)
ages.append(max_age)

ages.sort()
n = len(ages)

if n % 2 != 0:
    median_age = ages[n // 2]
else:
    median_age = (ages[n // 2 - 1] + ages[n // 2]) / 2

average_age = sum(ages) / len(ages)
age_range = max_age - min_age

diff_min = abs(min_age - average_age)
diff_max = abs(max_age - average_age)

print("Min:", min_age, "Max:", max_age)
print("Updated ages:", ages)
print("Median:", median_age)
print("Average:", average_age)
print("Range:", age_range)
print("Min diff:", diff_min, "Max diff:", diff_max)

# %%
countries = ["China", "Russia", "USA", "Finland", "Sweden", "Norway", "Denmark"]

n = len(countries)

if n % 2 != 0:
    middle = [countries[n // 2]]
else:
    middle = [countries[n // 2 - 1], countries[n // 2]]

print("Middle:", middle)

# %%
countries = ["China", "Russia", "USA", "Finland", "Sweden", "Norway", "Denmark"]

n = len(countries)
half = (n + 1) // 2

first_half = countries[:half]
second_half = countries[half:]

print("First half:", first_half)
print("Second half:", second_half)

# %%
countries_list = [
    "India",
    "Russia",
    "China",
    "Finland",
    "Sweden",
    "Norway",
    "Denmark",
]

first, second, third, *scandic_countries = countries_list

print(first, second, third)
print(scandic_countries)

# %% [markdown]
# ## 💻 Exercises ➞ <span class='label label-default'>Sets</span>
#
# ```py
# mix_fruits = {'Guava', 'Pear', 'Mango', 'Apple', 'Fig', 'Orange', 'Banana'}
# A = {19, 22, 24, 20, 25, 26}
# B = {19, 22, 20, 25, 26, 24, 28, 27}
# num = [22, 19, 24, 25, 26, 24, 25, 24]
# ```
#
# ### Exercises ➞ <span class='label label-default'>Level 1</span>
#
# 1. Create a tuple containing names of **`fruits`** and **`vegetables`**
# 2. Join **`fruits`** and **`vegetables`** tuples and assign it to **`fruits_vegetables`**
# 3. How many **`fruits_vegetables`** do you have?
# 4. Modify the **`fruits_vegetables`** tuple and add the name of your favorite mushroom and beverage and assign it to **`food_tuple`**
#
# ### Exercises ➞ <span class='label label-default'>Level 2</span>
#
# 1. Unpack **`fruits_vegetables`** and mushroom and beverage from **`food_tuple`**
# 2. Change the about **`food_tuple`** tuple to a **`food_list`** list
# 3. Slice out the middle item or items from the **`food_tuple`** tuple or **`food_list`** list.
# 4. Slice out the first three items and the last three items from **`food_list`** list
# 5. Delete the **`food_tuple`** tuple completely
# 6. Check if an item exists in tuple:
#     - Check if **`'Finland'`** is a asian country
#     - Check if **`'India'`** is a asian country
#     ```python
# asian_countries = ('India','China','Singapore','Thailand','Indonesia')
# ```

# %%
fruits = ("Apple", "Banana", "Orange")
vegetables = ("Tomato", "Carrot", "Onion")

fruits_vegetables = fruits + vegetables

print("Number of fruits and vegetables:", len(fruits_vegetables))

food_tuple = fruits_vegetables + ("Shiitake", "Coffee")


fruits_veg, mushroom, beverage = food_tuple

food_list = list(food_tuple)

n = len(food_list)
if n % 2 != 0:
    middle_items = food_list[n // 2]
else:
    middle_items = food_list[n // 2 - 1 : n // 2 + 1]
print("Middle item(s):", middle_items)

first_three = food_list[:3]
last_three = food_list[-3:]
print("First three:", first_three)
print("Last three:", last_three)

del food_tuple

asian_countries = ('India', 'China', 'Singapore', 'Thailand', 'Indonesia')

print("Is Finland an asian country?", 'Finland' in asian_countries)
print("Is India an asian country?", 'India' in asian_countries)

# %% [markdown]
# ---
#
# ## 💻 Exercises ➞ <span class='label label-default'>Dictionary</span>
#
# 1. Create an empty dictionary called **`bird`**
# 2. Add **`name`**, **`color`**, **`breed`**, **`legs`**, **`age`** to the **`bird`** dictionary
# 3. Create a **`student`** dictionary and add **`first_name`**, **`last_name`**, **`gender`**, **`age`**, **`marital_status`**, **`skills`**, **`country`**, **`city`** and **`address`** as keys for the dictionary
# 3. Get the length of the **`student`** dictionary
# 4. Get the value of **`skills`** and check the data type, it should be a list
# 5. Modify the **`skills`** values by adding one or two skills
# 6. Get the dictionary keys as a list
# 7. Get the dictionary values as a list
# 8. Change the dictionary to a list of tuples using **`items()`** method
# 9. Delete one of the items in the dictionary
# 10. Delete one of the dictionaries

# %%
bird = {}

bird['name'] = 'Falcon'
bird['color'] = 'Brown'
bird['breed'] = 'Peregrine'
bird['legs'] = 2
bird['age'] = 3

student = {
    'first_name': 'Alex',
    'last_name': 'Smith',
    'gender': 'Male',
    'age': 22,
    'marital_status': 'Single',
    'skills': ['Python', 'SQL'],
    'country': 'Egypt',
    'city': 'Cairo',
    'address': '123 Main St'
}

print("Student length:", len(student))

skills = student['skills']
print("Skills:", skills)
print("Skills type:", type(skills))

student['skills'].append('Excel')
student['skills'].append('Power BI')
print("Updated skills:", student['skills'])

keys_list = list(student.keys())
print("Keys:", keys_list)

values_list = list(student.values())
print("Values:", values_list)

student_tuples = list(student.items())
print("Tuples:", student_tuples)

del student['marital_status']
print("After deletion:", student)

del bird
